# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df0=pd.read_excel('admission-pred-AnalysedData.xlsx',index_col=0,header=0)  # reading the .xlsx file and creating a data frame
df=pd.DataFrame(df0)
df
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
# ...               ...          ...                ...  ...  ...   ...
# 496               332          108                  5  4.5  4.0  9.02
# 497               337          117                  5  5.0  5.0  9.87
# 498               330          120                  5  4.5  5.0  9.56
# 499               312          103                  4  4.0  5.0  8.43
# 500               327          113                  4  4.5  4.5  9.04
#
#             Research  Chance of Admit
# Serial No.
# 1                  1             0.92
# ...

# %%
df_corr=pd.DataFrame.corr(df,method='pearson',min_periods=1)

# %%
df_corr  # correlation matrix
# Out:
#                    GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score           1.000000     0.824109           0.633917  0.613922
# TOEFL Score         0.824109     1.000000           0.648554  0.648435
# University Rating   0.633917     0.648554           1.000000  0.727341
# SOP                 0.613922     0.648435           0.727341  1.000000
# LOR                 0.520115     0.546089           0.607391  0.665392
# CGPA                0.821921     0.809348           0.703957  0.711430
# Research            0.557336     0.466263           0.432625  0.407739
# Chance of Admit     0.803534     0.793507           0.688949  0.684354
#
#                         LOR      CGPA  Research  Chance of Admit
# GRE Score          0.520115  0.821921  0.557336         0.803534
# TOEFL Score        0.546089  0.809348  0.466263         0.793507
# University Rating  0.607391  0.703957  0.432625         0.688949
# SOP                0.665392  0.711430  0.407739         0.684354
# ...

# %%
plt.matshow(df_corr)   # raw corellation graph

# %%
#heatmap of the correlation of the data variables.
mask = np.zeros_like(df.corr(), dtype=np.bool)       # It returns array of zeros with the shape of df.corr
mask[np.triu_indices_from(mask)] = True              #Return the indices for the upper-triangle of an array.
plt.figure(figsize=(12,12))                          #Adjusted the figure size
sns.heatmap(df.corr(),mask=mask,annot=True,linewidths=1)   # This is used to plot rectangular data as a color-encoded matrix.
plt.show()
# As all the values are positive, we can conclude that all the variables are positively correlated to each other.

# %%
sns.pairplot(df,x_vars=labels[0:6], y_vars='Chance of Admit')     # This is used to plot pairwise relationships in a dataset
plt.tight_layout()
#Below is the histogram plot for visualising the relation between Chance of Admit and the other features
